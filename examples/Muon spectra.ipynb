# %% [markdown]
# # Muon spectra
#
# - prompt: mother has lifetime < D0

# %%
#basic imports and ipython setup
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
import os
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["font.size"] = 20
rcParams["figure.figsize"] = (7, 6)
from scipy.interpolate import interp1d
from scipy.integrate import trapz

import numpy as np
os.chdir('..')

#import solver related modules
from MCEq.core import MCEqRun
from mceq_config import config
#import primary model choices
import CRFluxModels as pm

# %%
interaction_models = (
    'DPMJet-III-2017.1',
    'DPMJet-III',
    'EPOS-LHC',
    'QGSJet-II-04',
    'QGSJet-II-03',
    'QGSJet-01',
    'SIBYLL-2.3.5',
    'SIBYLL-2.1',
)

cr_energy = {"auger": 1e10, "icecube": 1e8}
h_obs = {"auger": 1425, "icecube": 2835}
theta_deg = {"auger": 67, "icecube": 13}    

lepton_spectra = {}
height_grid = {}

# %%
for experiment in ("auger", "icecube"):
    if experiment not in lepton_spectra:
        lepton_spectra[experiment] = {}
    for interaction_model in interaction_models:
        if interaction_model in lepton_spectra[experiment]:
            print "skipping", interaction_model
            continue
        lepton_spectra[experiment][interaction_model] = {}
        for prim in ("proton", "iron"):
            print "=== processing", experiment, interaction_model, prim, "==="
            spectra = lepton_spectra[experiment][interaction_model][prim] = {}

            cfg = dict(config)
            cfg["density_model"] = {
                "icecube": ("MSIS00_IC", ("SouthPole", "January")),
                "auger": ("CORSIKA", ("BK_USStd", None)),
            }[experiment]
            cfg["h_obs"] = h_obs[experiment]
            mceq_run = MCEqRun(
                interaction_model,
                primary_model=(pm.HillasGaisser2012, 'H3a'),
                theta_deg=theta_deg[experiment],
                **cfg
            )

            a = {"proton": 1, "iron": 56}[prim]
            mceq_run.set_single_primary_particle(
                cr_energy[experiment],
                {"proton": 14, "iron": 5626}[prim]
            )

            Xvec = np.arange(1, mceq_run.density_model.max_X, 5)
            if experiment not in height_grid:
                height_grid[experiment] = (Xvec, mceq_run.density_model.s_lX2h(np.log(Xvec))/1e2)

            mceq_run.solve(int_grid=Xvec, grid_var="X")

            # muons
            spectra["egrid"] = mceq_run.e_grid
            for t in ("total", "conv", "pr"):
                spectra["mu_" + t] = (
                    mceq_run.get_solution(t + '_mu+', 0) +
                    mceq_run.get_solution(t + '_mu-', 0)
                )

            mu_long = np.empty_like(Xvec)
            for idx, X in enumerate(Xvec):
                y = (mceq_run.get_solution("total_mu+", 0, grid_idx=idx) +
                     mceq_run.get_solution("total_mu-", 0, grid_idx=idx))
                mu_long[idx] = trapz(y, mceq_run.e_grid)
            spectra["mu_long"] = mu_long

            if experiment == "icecube":
                for n in ("numu", "nue", "nutau"):
                    for t in ("total", "conv", "pr"):
                        # since there are no conventional tau neutrinos, prompt=total
                        if n == "nutau" and t != "total": continue
                        spectra[n + "_" + t] = (
                            mceq_run.get_solution(t + '_' + n, 0) +
                            mceq_run.get_solution(t + '_anti' + n, 0)
                        )
# Out:
# === processing auger DPMJet-III-2017.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII20171_yields_compact.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/DPMJETIII20171_yields.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII20171
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.56%
#     shape      : 5368 x 5368
#     nnz        : 1024693
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.15ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.47451400757 sec
# === processing auger DPMJet-III-2017.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII20171_yields_compact.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII20171
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.56%
#     shape      : 5368 x 5368
#     nnz        : 1024693
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.06ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.30931401253 sec
# === processing auger DPMJet-III proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII_yields_compact.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/DPMJETIII_yields.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.54%
#     shape      : 5368 x 5368
#     nnz        : 1021262
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.10ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.3582379818 sec
# === processing auger DPMJet-III iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII_yields_compact.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.54%
#     shape      : 5368 x 5368
#     nnz        : 1021262
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.12ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.380245924 sec
# === processing auger EPOS-LHC proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields.bz2
# extend_to_low_energies(): entering with True True None
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# extend_to_low_energies(): int. arrays [ 0.    0.25  0.5   0.75  1.  ] [13 14 15 16 17] [  49.20189143   65.61177673   87.49471047  116.67607161  155.59004211]
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161692
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.77ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.918040990829 sec
# === processing auger EPOS-LHC iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161692
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.79ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.937806844711 sec
# === processing auger QGSJet-II-04 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields.bz2
# extend_to_low_energies(): entering with True True None
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# extend_to_low_energies(): int. arrays [ 0.    0.25  0.5   0.75  1.  ] [13 14 15 16 17] [  49.20189143   65.61177673   87.49471047  116.67607161  155.59004211]
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.61%
#     shape      : 4840 x 4840
#     nnz        : 142260
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.97ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.15211296082 sec
# === processing auger QGSJet-II-04 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.61%
#     shape      : 4840 x 4840
#     nnz        : 142260
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.72ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.848649024963 sec
# === processing auger QGSJet-II-03 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII03_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/hdembins/miniconda2/MCEq/data/QGSJETII03_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/QGSJETII03_yields.bz2
# extend_to_low_energies(): entering with True True None
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# extend_to_low_energies(): int. arrays [ 0.    0.25  0.5   0.75  1.  ] [13 14 15 16 17] [  49.20189143   65.61177673   87.49471047  116.67607161  155.59004211]
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII03
# InteractionYields:set_interaction_model():: Model QGSJETII03 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII03 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.62%
#     shape      : 4840 x 4840
#     nnz        : 613522
# D Matrix info:
#     density    : 0.61%
#     shape      : 4840 x 4840
#     nnz        : 142404
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.70ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.824368000031 sec
# === processing auger QGSJet-II-03 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII03_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII03
# InteractionYields:set_interaction_model():: Model QGSJETII03 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII03 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.62%
#     shape      : 4840 x 4840
#     nnz        : 613522
# D Matrix info:
#     density    : 0.61%
#     shape      : 4840 x 4840
#     nnz        : 142404
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.85ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.00943589211 sec
# === processing auger QGSJet-01 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJET01_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/hdembins/miniconda2/MCEq/data/QGSJET01_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/QGSJET01_yields.bz2
# extend_to_low_energies(): entering with True True None
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# extend_to_low_energies(): int. arrays [ 0.    0.25  0.5   0.75  1.  ] [13 14 15 16 17] [  49.20189143   65.61177673   87.49471047  116.67607161  155.59004211]
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 59
# MCEqRun::set_interaction_model():  QGSJET01
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.22%
#     shape      : 5192 x 5192
#     nnz        : 867624
# D Matrix info:
#     density    : 0.76%
#     shape      : 5192 x 5192
#     nnz        : 205382
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   0.91ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.12400507927 sec
# === processing auger QGSJet-01 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJET01_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 59
# MCEqRun::set_interaction_model():  QGSJET01
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.22%
#     shape      : 5192 x 5192
#     nnz        : 867624
# D Matrix info:
#     density    : 0.76%
#     shape      : 5192 x 5192
#     nnz        : 205382
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.41ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.73880195618 sec
# === processing auger SIBYLL-2.3.5 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields.bz2
# extend_to_low_energies(): entering with True True None
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# extend_to_low_energies(): int. arrays [ 0.    0.25  0.5   0.75  1.  ] [13 14 15 16 17] [  49.20189143   65.61177673   87.49471047  116.67607161  155.59004211]
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.05ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.29315400124 sec
# === processing auger SIBYLL-2.3.5 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.25ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.54328918457 sec
# === processing auger SIBYLL-2.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields.bz2
# extend_to_low_energies(): entering with True True None
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# extend_to_low_energies(): int. arrays [ 0.    0.25  0.5   0.75  1.  ] [13 14 15 16 17] [  49.20189143   65.61177673   87.49471047  116.67607161  155.59004211]
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161872
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.73ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.866865873337 sec
# === processing auger SIBYLL-2.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161872
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.74ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.876578092575 sec
# === processing icecube DPMJet-III-2017.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII20171_yields_compact.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII20171
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.56%
#     shape      : 5368 x 5368
#     nnz        : 1024693
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.62s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.10ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.566246032715 sec
# === processing icecube DPMJet-III-2017.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII20171_yields_compact.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII20171
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII20171 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.56%
#     shape      : 5368 x 5368
#     nnz        : 1024693
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.43s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.12ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.576695919037 sec
# === processing icecube DPMJet-III proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII_yields_compact.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.54%
#     shape      : 5368 x 5368
#     nnz        : 1021262
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.56s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.09ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.56508398056 sec
# === processing icecube DPMJet-III iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/DPMJETIII_yields_compact.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
# DecayYields::_load(): Warning: no decay distributions for 16 found.
# DecayYields::_load(): Warning: no decay distributions for -16 found.
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  DPMJETIII
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# InteractionYields:set_interaction_model():: Model DPMJETIII already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.54%
#     shape      : 5368 x 5368
#     nnz        : 1021262
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.55s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.12ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.580592155457 sec
# === processing icecube EPOS-LHC proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161692
# ...
# Performance:   0.75ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.371911048889 sec
# === processing icecube QGSJet-II-03 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII03_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII03
# InteractionYields:set_interaction_model():: Model QGSJETII03 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII03 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.62%
#     shape      : 4840 x 4840
#     nnz        : 613522
# D Matrix info:
#     density    : 0.61%
#     shape      : 4840 x 4840
#     nnz        : 142404
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.69s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.76ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.375931978226 sec
# === processing icecube QGSJet-01 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJET01_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 59
# MCEqRun::set_interaction_model():  QGSJET01
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.22%
#     shape      : 5192 x 5192
#     nnz        : 867624
# D Matrix info:
#     density    : 0.76%
#     shape      : 5192 x 5192
#     nnz        : 205382
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.59s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   0.94ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.488103151321 sec
# === processing icecube QGSJet-01 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJET01_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 59
# MCEqRun::set_interaction_model():  QGSJET01
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJET01 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.22%
#     shape      : 5192 x 5192
#     nnz        : 867624
# D Matrix info:
#     density    : 0.76%
#     shape      : 5192 x 5192
#     nnz        : 205382
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.45s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.02ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.525696992874 sec
# === processing icecube SIBYLL-2.3.5 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.68s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.23ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.633692026138 sec
# === processing icecube SIBYLL-2.3.5 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 0.90%
#     shape      : 5368 x 5368
#     nnz        : 259912
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.43s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.08ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.560422897339 sec
# === processing icecube SIBYLL-2.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161872
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.47s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.77ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.383427858353 sec
# === processing icecube SIBYLL-2.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.69%
#     shape      : 4840 x 4840
#     nnz        : 161872
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.46s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.79ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.392651081085 sec

# %% [markdown]
# # Plot with matplotlib

# %%
def model_color(name):
    model_colors = {"EPOS-LHC": "k",
                    "SIBYLL-2.3": "b",
                    "SIBYLL-2.1": "m", 
                    "DPMJet" : "g",
                    "QGSJet" : "r",
                    "QGSJet-01": "0.5"}
    for k,v in model_colors.items():
        if name.startswith(k):
            return v

def model_linestyle(name):
    if name in ("EPOS-LHC", "SIBYLL-2.3.5", "DPMJet-III-2017.1", "QGSJet-II-04"):
        return "-"
    else:
        return ":"

# %%
# atmoshpere
for experiment, (X, h) in height_grid.items():
    plt.figure()
    plt.title({
        "auger": r"Auger: 1425 m, $\theta = 67^\circ$",
        "icecube": r"IceCube: 2835 m, $\theta = 13^\circ$",
    }[experiment])
    plt.plot(h/1e3, X, "k-")
    plt.axvspan(0, h_obs[experiment]/1e3, color="k", alpha=0.2)
    x_ground = interp1d(h, X)(h_obs[experiment])
    print "%s %.0f gcm-2" % (experiment, x_ground)
    plt.xlim(0, 50)
    plt.xlabel("$h$/km")
    plt.ylabel("$X_\mathrm{atm}/\mathrm{g\,cm^{-2}}$")
    #plt.semilogy()
# Out:
# auger 2209 gcm-2
# icecube 718 gcm-2

# %%
# longitudinal
h_mu_max = {"auger": 0.0, "icecube": 0.0}

for experiment in lepton_spectra:
    X, h = height_grid[experiment]
    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]

        plt.figure()
        plt.title({
            "auger": r"Auger: 1425 m, $E_0 = 10^{10}\,$GeV $\theta = 67^\circ$",
            "icecube": r"IceCube: 2835 m, $E_0 = 10^8\,$GeV $\theta = 13^\circ$",
        }[experiment], x=0.55)
        for prim, spectra in prim_spectra.items():
            y = spectra["mu_long"]
            color = {"proton" : "r", "iron": "b"}[prim]
            label = {"proton" : "p", "iron": "Fe"}[prim] 
            plt.plot(h/1e3, y, "k-", color=color, label=prim)
            hm = h[np.argmax(y)]
            h_mu_max[experiment] += hm
            print "%s %s h_mu_max %.1f km" % (experiment, prim, hm/1e3)
        print "ratio", prim_spectra["iron"]["mu_long"][-1]/prim_spectra["proton"]["mu_long"][-1]
        plt.xlim(0, 20)
        plt.legend(title=interaction_model)
        plt.axvspan(0, h_obs[experiment]/1e3, color="k", alpha=0.2)
        plt.xlabel("$h$/km")
        plt.ylabel("$N_\mu(E_\mu > 1\,\mathrm{GeV})$")

for k, v in h_mu_max.items():
    h_mu_max[k] = v/2
    print "%s avg h_mu_max %.1f km" % (experiment, v/2e3)
# Out:
# auger iron h_mu_max 8.9 km
# auger proton h_mu_max 8.3 km
# ratio 1.61719328909
# auger iron h_mu_max 8.8 km
# auger proton h_mu_max 8.3 km
# ratio 1.67822572324
# auger iron h_mu_max 7.9 km
# auger proton h_mu_max 7.4 km
# ratio 1.4849042592
# auger iron h_mu_max 8.0 km
# auger proton h_mu_max 7.5 km
# ratio 1.51975436118
# auger iron h_mu_max 8.0 km
# auger proton h_mu_max 7.6 km
# ratio 1.48733535843
# auger iron h_mu_max 8.4 km
# auger proton h_mu_max 7.9 km
# ratio 1.46300154293
# auger iron h_mu_max 8.0 km
# auger proton h_mu_max 7.5 km
# ratio 1.54047198533
# auger iron h_mu_max 8.5 km
# auger proton h_mu_max 8.0 km
# ratio 1.7480981527
# icecube iron h_mu_max 2.5 km
# icecube proton h_mu_max 1.7 km
# ratio 1.61541184683
# icecube iron h_mu_max 2.5 km
# icecube proton h_mu_max 1.7 km
# ratio 1.68538069272
# icecube iron h_mu_max 1.6 km
# icecube proton h_mu_max 0.7 km
# ratio 1.51972312395
# icecube iron h_mu_max 1.5 km
# icecube proton h_mu_max 0.7 km
# ratio 1.5868401274
# icecube iron h_mu_max 1.5 km
# icecube proton h_mu_max 0.8 km
# ratio 1.61447388789
# icecube iron h_mu_max 2.0 km
# icecube proton h_mu_max 1.2 km
# ratio 1.53873420537
# icecube iron h_mu_max 1.6 km
# icecube proton h_mu_max 0.7 km
# ratio 1.54462462575
# icecube iron h_mu_max 2.1 km
# icecube proton h_mu_max 1.3 km
# ratio 1.71324016961
# icecube avg h_mu_max 64.5 km
# icecube avg h_mu_max 12.1 km

# %%
# comparions: total number of muons at ground
for experiment in lepton_spectra:
    X, h = height_grid[experiment]
    lnrmu = OrderedDict()
    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]

        for prim, spectra in prim_spectra.items():
            y = spectra["mu_long"]            
            nmu = y[np.argmin(np.abs(h-h_obs[experiment]))]
            lnrmu[(interaction_model, prim)] = np.log(nmu)
    print experiment
    for y, key in enumerate(lnrmu.keys()):
        model, prim = key
        x = lnrmu[key] - lnrmu[("QGSJet-II-03", "proton")]
        print "%19s %2s %6.3f" % (model, {"proton":"p", "iron":"Fe"}[prim], x)
# Out:
# auger
#   DPMJet-III-2017.1 Fe  0.427
#   DPMJet-III-2017.1  p -0.042
#          DPMJet-III Fe  0.336
#          DPMJet-III  p -0.171
#            EPOS-LHC Fe  0.635
#            EPOS-LHC  p  0.252
#        QGSJet-II-04 Fe  0.539
#        QGSJet-II-04  p  0.131
#        QGSJet-II-03 Fe  0.388
#        QGSJet-II-03  p  0.000
#           QGSJet-01 Fe  0.517
#           QGSJet-01  p  0.146
#        SIBYLL-2.3.5 Fe  0.648
#        SIBYLL-2.3.5  p  0.228
#          SIBYLL-2.1 Fe  0.050
#          SIBYLL-2.1  p -0.498
# icecube
#   DPMJet-III-2017.1 Fe  0.864
#   DPMJet-III-2017.1  p  0.294
#          DPMJet-III Fe  0.742
#          DPMJet-III  p  0.132
#            EPOS-LHC Fe  0.799
#            EPOS-LHC  p  0.251
#        QGSJet-II-04 Fe  0.692
#        QGSJet-II-04  p  0.123
#        QGSJet-II-03 Fe  0.583
#        QGSJet-II-03  p  0.000
#           QGSJet-01 Fe  0.743
#           QGSJet-01  p  0.222
#        SIBYLL-2.3.5 Fe  0.813
#        SIBYLL-2.3.5  p  0.266
#          SIBYLL-2.1 Fe  0.382
#          SIBYLL-2.1  p -0.241

# %%
# muon spectra 1
for experiment in lepton_spectra:
    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]

        plt.figure()
        plt.title({
            "auger": r"Auger: 1425 m, $E_0 = 10^{10}\,$GeV $\theta = 67^\circ$",
            "icecube": r"IceCube: 2835 m, $E_0 = 10^8\,$GeV $\theta = 13^\circ$",
        }[experiment])
        for prim, spectra in prim_spectra.items():
            x = spectra["egrid"]
            y1 = spectra["mu_total"]
            y2 = spectra["mu_pr"]
            color = {"proton" : "r", "iron": "b"}[prim]
            label = {"proton" : "p", "iron": "Fe"}[prim] 
            plt.plot(x, y1, "k-", color=color, lw=2, label=label + " total")
            plt.plot(x, y2, "k:", color=color, label=label + " prompt")
        plt.loglog()
        plt.xlim(1, 1e8)
        plt.ylim(1e-14, 1e7)
        plt.xlabel(r"$E_\mu$/GeV")
        plt.legend(title=interaction_model)

# %%
# muon spectra 2
from collections import OrderedDict
for experiment in lepton_spectra:        
    plt.figure(figsize=(10, 5))
    plt.title({
        "auger": r"Auger: 1425 m, p, $E_0 = 10^{10}\,$GeV, $\theta = 67^\circ$",
        "icecube": r"IceCube: 2835 m, p, $E_0 = 10^8\,$GeV, $\theta = 13^\circ$",
    }[experiment], x=0.5)

    y = OrderedDict()
    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        if model_linestyle(interaction_model) != "-" and interaction_model != "SIBYLL-2.1":
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]
        spectra = prim_spectra["proton"]
        y[interaction_model] = spectra["mu_total"]
        x = spectra["egrid"]

    for interaction_model, yi in y.items():
        plt.plot(x, yi / y["EPOS-LHC"], "-",
                 color=model_color(interaction_model), label=interaction_model)
    plt.semilogx()
    plt.ylim(0., 2)
    plt.xlim(1, 1e3)
    plt.xlabel(r"$E_\mu$/GeV")
    plt.ylabel("muon spectrum relative to EPOS-LHC")
    plt.subplots_adjust(right=0.7)
    plt.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
# Out:
# /Users/hdembins/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in divide

# %%
# muon spectra ratios
for experiment in lepton_spectra:
    ratios = []

    plt.figure(figsize=(10, 5))
    plt.title({
        "auger": r"Auger: 1425 m, $E_0 = 10^{10}\,$GeV $\theta = 67^\circ$",
        "icecube": r"IceCube: 2835 m, $E_0 = 10^8\,$GeV $\theta = 13^\circ$",
    }[experiment], x=0.55)

    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]
        ratio = prim_spectra["iron"]["mu_total"] / prim_spectra["proton"]["mu_total"]
        xiron = prim_spectra["iron"]["egrid"]
        xproton = prim_spectra["proton"]["egrid"]
        assert(np.all(xiron == xproton))
        
        ratios.append(ratio)
        plt.plot(x, ratio,
                 color=model_color(interaction_model),
                 ls=model_linestyle(interaction_model),
                 label=interaction_model)
        plt.semilogx()
        plt.xlim(1, cr_energy[experiment]/1e2)
        plt.ylim(1, 3.2)
        plt.xlabel(r"$E_\mu$/GeV")
        plt.ylabel(r"iron / proton")
    plt.subplots_adjust(right=0.65)
    plt.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))

    plt.figure()
    plt.title({
        "auger": r"Auger: 1425 m, $E_0 = 10^{10}\,$GeV $\theta = 67^\circ$",
        "icecube": r"IceCube: 2835 m, $E_0 = 10^8\,$GeV $\theta = 13^\circ$",
    }[experiment])

    m = np.mean(ratios, axis=0)
    d = np.zeros_like(m)
    for r in ratios:
        a = np.abs(r-m)
        d[d<a] = a[d<a]
    s = np.var(ratios, axis=0) ** 0.5
    plt.plot(xproton, m/d)
    plt.semilogx()
    plt.xlim(1, cr_energy[experiment]/1e2)
    plt.xlabel(r"$E_\mu$/GeV")
    plt.ylabel(r"(average iron/proton ratio) / (model spread)")
# Out:
# /Users/hdembins/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in divide
#   from ipykernel import kernelapp as app
# /Users/hdembins/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:43: RuntimeWarning: invalid value encountered in less
# /Users/hdembins/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %%
# neutrino spectra
for interaction_model, prim_spectra in lepton_spectra["icecube"].items():
    plt.figure()
    plt.title(r"IceCube: 2835 m, $E_0 = 10^8\,$GeV $\theta = 13^\circ$")
    for prim, spectra in prim_spectra.items():
        x = spectra["egrid"]
        y1 = spectra["numu_total"]
        y2 = spectra["numu_pr"]
        color = {"proton" : "r", "iron": "b"}[prim]
        label = {"proton" : "p", "iron": "Fe"}[prim] 
        plt.plot(x, y1, "k-", color=color, lw=2, label=label + " total")
        plt.plot(x, y2, "k:", color=color, label=label + " prompt")
    plt.loglog()
    plt.xlim(1, 1e8)
    plt.ylim(1e-14, 1e7)
    plt.xlabel(r"$E_{\nu_\mu}$/GeV")
    plt.legend(title=interaction_model)
