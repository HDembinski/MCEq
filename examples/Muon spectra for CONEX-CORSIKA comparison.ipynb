# %%
#basic imports and ipython setup
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
import os
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["font.size"] = 20
rcParams["figure.figsize"] = (7, 6)
from scipy.interpolate import interp1d
from scipy.integrate import trapz
from collections import OrderedDict

import numpy as np
os.chdir('..')

#import solver related modules
from MCEq.core import MCEqRun
from mceq_config import config
#import primary model choices
import CRFluxModels as pm

# %%
interaction_models = (
    'EPOS-LHC',
    'QGSJet-II-04',
    'SIBYLL-2.3.5',
    'SIBYLL-2.1',
)

# E0, h_obs, theta_deg, density_model
experiments = {
    "auger": (1e10, 1425, 67, ("CORSIKA", ("BK_USStd", None))),
    "icecube": (1e8, 2835, 13, ("MSIS00_IC", ("SouthPole", "January"))),
    "felix1": (2e6, 0, 60, ("CORSIKA", ("BK_USStd", None))),
    "felix2": (2e10, 0, 60, ("CORSIKA", ("BK_USStd", None))),
}

lepton_spectra = {}

# %%
for experiment in experiments:
    if experiment not in lepton_spectra:
        lepton_spectra[experiment] = {}
    for interaction_model in interaction_models:
        if interaction_model in lepton_spectra[experiment]:
            print "skipping", interaction_model
            continue
        lepton_spectra[experiment][interaction_model] = {}
        for prim in ("proton", "iron"):
            print "=== processing", experiment, interaction_model, prim, "==="
            spectra = lepton_spectra[experiment][interaction_model][prim] = {}

            cr_energy, h_obs, theta_deg, density_model = experiments[experiment]
            
            cfg = dict(config)
            cfg["density_model"] = density_model
            cfg["h_obs"] = h_obs
            mceq_run = MCEqRun(
                interaction_model,
                primary_model=(pm.HillasGaisser2012, 'H3a'),
                theta_deg=theta_deg,
                **cfg
            )

            a = {"proton": 1, "iron": 56}[prim]
            mceq_run.set_single_primary_particle(
                cr_energy,
                {"proton": 14, "iron": 5626}[prim]
            )

            Xvec = np.arange(1, mceq_run.density_model.max_X, 5)
            idx = np.argmin(np.abs(Xvec - 1000))

            mceq_run.solve(int_grid=Xvec, grid_var="X")

            spectra["egrid"] = mceq_run.e_grid
            for t in ("total", "conv", "pr"):
                if experiment.startswith("felix"):
                    spectra["mu_" + t] = (
                        mceq_run.get_solution(t + '_mu+', grid_idx=idx) +
                        mceq_run.get_solution(t + '_mu-', grid_idx=idx)
                    )
                else:
                    spectra["mu_" + t] = (
                        mceq_run.get_solution(t + '_mu+') +
                        mceq_run.get_solution(t + '_mu-')
                    )
# Out:
# === processing auger EPOS-LHC proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   1.00ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.2255051136 sec
# === processing auger EPOS-LHC iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.99ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.1711230278 sec
# === processing auger QGSJet-II-04 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   1.07ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.27165985107 sec
# === processing auger QGSJet-II-04 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.75ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.894032001495 sec
# === processing auger SIBYLL-2.3.5 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.06ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.30365395546 sec
# === processing auger SIBYLL-2.3.5 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1234 integration steps.
# Performance:   1.26ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.5530629158 sec
# === processing auger SIBYLL-2.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.85ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.00878000259 sec
# === processing auger SIBYLL-2.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  67
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2629.3456982
# MCEqRun::_forward_euler(): Solver will perform 1184 integration steps.
# Performance:   0.75ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.891661882401 sec
# === processing felix1 EPOS-LHC proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.79ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.744601011276 sec
# === processing felix1 EPOS-LHC iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   1.04ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.974760055542 sec
# === processing felix1 QGSJet-II-04 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.87ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.815406084061 sec
# === processing felix1 QGSJet-II-04 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.92ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.8670399189 sec
# === processing felix1 SIBYLL-2.3.5 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 981 integration steps.
# Performance:   1.12ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.10431694984 sec
# === processing felix1 SIBYLL-2.3.5 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 981 integration steps.
# Performance:   1.07ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.05414891243 sec
# === processing felix1 SIBYLL-2.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.78ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.73398900032 sec
# === processing felix1 SIBYLL-2.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+06 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.80ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.754333019257 sec
# === processing felix2 EPOS-LHC proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.89ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.832446098328 sec
# === processing felix2 EPOS-LHC iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.80ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.750149011612 sec
# === processing felix2 QGSJet-II-04 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.75ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.703119039536 sec
# === processing felix2 QGSJet-II-04 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.74ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.694805860519 sec
# === processing felix2 SIBYLL-2.3.5 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 981 integration steps.
# Performance:   1.35ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.32726383209 sec
# === processing felix2 SIBYLL-2.3.5 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 981 integration steps.
# Performance:   1.51ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.4783539772 sec
# === processing felix2 SIBYLL-2.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  60
# atmospheres::_load_cache(): loading cache.
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=2e+10 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 2060.59588842
# MCEqRun::_forward_euler(): Solver will perform 938 integration steps.
# Performance:   0.89ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.840190887451 sec
# === processing felix2 SIBYLL-2.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# ...
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.83ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.413074016571 sec
# === processing icecube EPOS-LHC iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/EPOSLHC_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  EPOSLHC
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# InteractionYields:set_interaction_model():: Model EPOSLHC already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.06%
#     shape      : 4840 x 4840
#     nnz        : 716895
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200726
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.43s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.82ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.408493995667 sec
# === processing icecube QGSJet-II-04 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.48s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.79ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.390465021133 sec
# === processing icecube QGSJet-II-04 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/QGSJETII04_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "obs_mu-", "pr_mu+", "k_mu-", "pi_mu+", "pi_mu-", "pr_mu-", "obs_mu+", "k_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  QGSJETII04
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# InteractionYields:set_interaction_model():: Model QGSJETII04 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.72%
#     shape      : 4840 x 4840
#     nnz        : 636704
# D Matrix info:
#     density    : 0.77%
#     shape      : 4840 x 4840
#     nnz        : 181294
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.43s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.93ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.459319829941 sec
# === processing icecube SIBYLL-2.3.5 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.60s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.12ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.578037023544 sec
# === processing icecube SIBYLL-2.3.5 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL235_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL235
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL235 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981217
# D Matrix info:
#     density    : 1.04%
#     shape      : 5368 x 5368
#     nnz        : 298946
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.42s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 516 integration steps.
# Performance:   1.07ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.553577899933 sec
# === processing icecube SIBYLL-2.1 proton ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.53s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=14, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.93ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.462381839752 sec
# === processing icecube SIBYLL-2.1 iron ===
# InteractionYields::_load(): Looking for /Users/hdembins/miniconda2/MCEq/data/SIBYLL21_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /Users/hdembins/miniconda2/MCEq/data/decays_v1_compact.ppd
#
# Hadrons and stable particles:
#
# "gamma", "p", "p-bar", "n", "n-bar"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue", "k_numu",
# "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau", "k_antinutau",
# "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau", "obs_antinumu",
# "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-", "obs_mu+"
#
# Total number of species: 55
# MCEqRun::set_interaction_model():  SIBYLL21
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL21 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 2.83%
#     shape      : 4840 x 4840
#     nnz        : 663087
# D Matrix info:
#     density    : 0.86%
#     shape      : 4840 x 4840
#     nnz        : 200906
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  MSIS00_IC ('SouthPole', 'January')
# MCEqRun::set_theta_deg():  13
# MSIS00IceCubeCentered::set_theta(): latitude = -89.9959681595 for zenith angle = 13
# MSIS00IceCubeCentered::calculate_density_spline(): Calculating spline of rho(X) for zenith 13 degrees.
# .. took 1.51s
# Average spline error: 1.96324350988e-16
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_single_primary_particle(): corsika_id=5626, particle energy=1e+08 GeV
# MCEqRun::_calculate_integration_path(): X_surface = 1049.52645783
# MCEqRun::_forward_euler(): Solver will perform 495 integration steps.
# Performance:   0.83ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.409713029861 sec

# %%
def model_color(name):
    model_colors = {"EPOS-LHC": "g",
                    "SIBYLL-2.3": "r",
                    "SIBYLL-2.1": "b", 
                    "QGSJet-II-04" : "m"}
    for k,v in model_colors.items():
        if name.startswith(k):
            return v

# %%
# muon spectra 1
for experiment in ("felix1", "felix2"):
    plt.figure()
    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]

        plt.title({
            "felix1": r"E0 = 2 PeV, X = 1000 gcm-2, $\theta$ = 60 deg",
            "felix2": r"E0 = 20 EeV, X = 1000 gcm-2, $\theta$ = 60 deg",
        }[experiment], x=0.55)
        for prim, spectra in prim_spectra.items():
            x = spectra["egrid"]
            y = spectra["mu_total"]
            label = {"proton" : "p", "iron": "Fe"}[prim]
            plt.plot(x, y * x ** 2, "-" if prim == "proton" else "--",
                     color=model_color(interaction_model),
                     label=prim + " " + interaction_model)
        plt.loglog()
        plt.xlim(1, 2e4 if experiment == "icecube" else 2e8)
        plt.legend()

# %%
# muon spectra ratio
for experiment in ("felix1", "felix2"):
    plt.figure(figsize=(10, 5))
    for interaction_model in interaction_models:
        if interaction_model not in lepton_spectra[experiment]:
            continue
        prim_spectra = lepton_spectra[experiment][interaction_model]

        plt.title("iron / proton: " + {
            "felix1": r"E0 = 2 PeV, X = 1000 gcm-2, $\theta$ = 60 deg",
            "felix2": r"E0 = 20 EeV, X = 1000 gcm-2, $\theta$ = 60 deg",
        }[experiment], x=0.55)
        
        x = prim_spectra["proton"]["egrid"]
        with np.errstate(invalid="ignore"):
            y = prim_spectra["iron"]["mu_total"] / prim_spectra["proton"]["mu_total"]
        plt.plot(x, y, "-",
                 color=model_color(interaction_model),
                 label=interaction_model)
        plt.semilogx()
        if experiment == "felix1":
            plt.xticks(10 ** np.arange(0, 5))
            plt.yticks((1.0, 1.5, 2.0, 2.5, 3.0))
            plt.xlim(1, 2e4)
            plt.ylim(1, 3.1)
        else:
            plt.xlim(1, 2e8)
            plt.ylim(1, 2.3)
            plt.xticks(10 ** np.arange(0, 9))
            plt.yticks((1, 1.5, 2.0))
        plt.xlabel("muon energy (GeV)")
        plt.ylabel("ratio of energy spectra")
        plt.legend(fontsize="small")
        plt.savefig({"felix1": "two_pev.pdf", "felix2": "two_eev.pdf"}[experiment])

# %%
# comparion with Auger PRD 2015 paper: total number of muons at ground
rmu_unit = 1.455e7 # muons with Emu > 0.3 GeV for theta = 67 deg
lnrmu = OrderedDict()
increase = []
print "number of muons at ground for auger"
for interaction_model in interaction_models:
    if interaction_model not in lepton_spectra["auger"]:
        continue
    prim_spectra = lepton_spectra["auger"][interaction_model]

    for prim, spectra in prim_spectra.items():
        x = spectra["egrid"]
        y = spectra["mu_total"]
        nmu1 = np.trapz(y, x)
        x1 = np.append([0.3], x)
        y1 = np.append(y[0], y)
        nmu2 = np.trapz(y1, x1)
        increase.append(nmu2 / nmu1)
        print interaction_model, prim, "%.3f x 1e7" % (nmu2 / 1e7)
        lnrmu[(interaction_model, prim)] = np.log(nmu2 / rmu_unit)
print "average increase from lowering threshold", np.mean(increase)
print "lnRmu like in Auger Paper:"
for y, key in enumerate(lnrmu.keys()):
    model, prim = key
    x = lnrmu[key]
    print "%19s %2s %6.3f" % (model, {"proton":"p", "iron":"Fe"}[prim], x)
# Out:
# number of muons at ground for auger
# EPOS-LHC iron 2.174 x 1e7
# EPOS-LHC proton 1.471 x 1e7
# QGSJet-II-04 iron 1.998 x 1e7
# QGSJet-II-04 proton 1.320 x 1e7
# SIBYLL-2.3.5 iron 2.217 x 1e7
# SIBYLL-2.3.5 proton 1.446 x 1e7
# SIBYLL-2.1 iron 1.233 x 1e7
# SIBYLL-2.1 proton 0.708 x 1e7
# average increase from lowering threshold 1.05761518428
# lnRmu like in Auger Paper:
#            EPOS-LHC Fe  0.401
#            EPOS-LHC  p  0.011
#        QGSJet-II-04 Fe  0.317
#        QGSJet-II-04  p -0.097
#        SIBYLL-2.3.5 Fe  0.421
#        SIBYLL-2.3.5  p -0.006
#          SIBYLL-2.1 Fe -0.165
#          SIBYLL-2.1  p -0.720
